# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
well_0 = pd.read_csv("well_0.csv")

# %%
well_0.shape
# Out:
# (29754, 18)

# %%
well_0.describe()
# Out:
#          Unnamed: 0  WELLNUM         DEPTH          DTC  DTS   BS  \
# count  29754.000000  29754.0  29754.000000  7007.000000  0.0  0.0
# mean   14876.500000      0.0   7773.410105    79.498714  NaN  NaN
# std     8589.384291      0.0   4294.692146    18.390705  NaN  NaN
# min        0.000000      0.0    335.160105     1.025100  NaN  NaN
# 25%     7438.250000      0.0   4054.285105    66.154350  NaN  NaN
# 50%    14876.500000      0.0   7773.410105    74.661900  NaN  NaN
# 75%    22314.750000      0.0  11492.535105    93.304550  NaN  NaN
# max    29753.000000      0.0  15211.660105   181.813900  NaN  NaN
#
#               CALI          DEN  DENC            GR          NEU  PEF  \
# count  7007.000000  7084.000000   0.0  28117.000000  7096.000000  0.0
# mean      9.611068     2.449055   NaN     71.986798     0.201172  NaN
# std       1.019751     0.165122   NaN     32.922780     0.147295  NaN
# min       6.000000     1.943000   NaN      2.766100     0.021783  NaN
# ...

# %%
well_0_PHIF=well_0.loc[well_0.PHIF.notnull() ]
well_0_SW=well_0.loc[well_0.SW.notnull()]
well_0_VSH=well_0.loc[well_0.VSH.notnull()]

# %%
well_0_PHIF.head()
# Out:
#        Unnamed: 0  WELLNUM         DEPTH       DTC  DTS  BS     CALI     DEN  \
# 22748       22748        0  11709.160105  132.2417  NaN NaN  12.9852  2.2937
# 22749       22749        0  11709.660105  123.9160  NaN NaN  12.6257  2.3030
# 22750       22750        0  11710.160105  115.0600  NaN NaN  12.7729  2.2769
# 22751       22751        0  11710.660105  121.8756  NaN NaN  11.7686  2.2808
# 22752       22752        0  11711.160105  125.3476  NaN NaN  11.6190  2.3272
#
#        DENC       GR       NEU  PEF    RDEP    RMED  ROP      PHIF   SW  VSH
# 22748   NaN  62.7379  0.420963  NaN  1.1841  0.7821  NaN  0.184759  1.0  NaN
# 22749   NaN  53.8436  0.742682  NaN  0.8829  1.0759  NaN  0.180910  1.0  NaN
# 22750   NaN  52.8516  0.459793  NaN  0.9517  0.9199  NaN  0.172497  1.0  NaN
# 22751   NaN  58.2263  0.499141  NaN  0.8684  1.2420  NaN  0.161982  1.0  NaN
# 22752   NaN  57.3380  0.600855  NaN  0.8296  0.9622  NaN  0.149478  1.0  NaN

# %%
well_0_SW.head()
# Out:
#        Unnamed: 0  WELLNUM         DEPTH       DTC  DTS  BS     CALI     DEN  \
# 22748       22748        0  11709.160105  132.2417  NaN NaN  12.9852  2.2937
# 22749       22749        0  11709.660105  123.9160  NaN NaN  12.6257  2.3030
# 22750       22750        0  11710.160105  115.0600  NaN NaN  12.7729  2.2769
# 22751       22751        0  11710.660105  121.8756  NaN NaN  11.7686  2.2808
# 22752       22752        0  11711.160105  125.3476  NaN NaN  11.6190  2.3272
#
#        DENC       GR       NEU  PEF    RDEP    RMED  ROP      PHIF   SW  VSH
# 22748   NaN  62.7379  0.420963  NaN  1.1841  0.7821  NaN  0.184759  1.0  NaN
# 22749   NaN  53.8436  0.742682  NaN  0.8829  1.0759  NaN  0.180910  1.0  NaN
# 22750   NaN  52.8516  0.459793  NaN  0.9517  0.9199  NaN  0.172497  1.0  NaN
# 22751   NaN  58.2263  0.499141  NaN  0.8684  1.2420  NaN  0.161982  1.0  NaN
# 22752   NaN  57.3380  0.600855  NaN  0.8296  0.9622  NaN  0.149478  1.0  NaN

# %%
well_0_VSH.head()
# Out:
#        Unnamed: 0  WELLNUM         DEPTH       DTC  DTS  BS    CALI     DEN  \
# 27573       27573        0  14121.660105   89.6461  NaN NaN  9.9048  2.5777
# 27574       27574        0  14122.160105   96.0152  NaN NaN  9.9912  2.4748
# 27575       27575        0  14122.660105  104.0457  NaN NaN  9.9048  2.3338
# 27576       27576        0  14123.160105  113.5010  NaN NaN  9.9048  2.2358
# 27577       27577        0  14123.660105  117.7817  NaN NaN  9.8095  2.2278
#
#        DENC        GR       NEU  PEF    RDEP    RMED  ROP  PHIF   SW       VSH
# 27573   NaN   88.8573  0.277790  NaN  2.6310  2.4927  NaN   0.0  1.0  0.751631
# 27574   NaN  120.8949  0.294806  NaN  2.4760  2.4685  NaN   0.0  1.0  1.032475
# 27575   NaN  153.5195  0.447361  NaN  2.4359  2.3742  NaN   0.0  1.0  1.312757
# 27576   NaN  182.8531  0.579637  NaN  2.4065  2.4142  NaN   0.0  1.0  1.682292
# 27577   NaN  256.1960  0.556317  NaN  2.3365  2.4077  NaN   0.0  1.0  1.924398

# %%
well_0_VSH.DEPTH.min()
# Out:
# 14121.6601049869

# %%
well_0_VSH.DEPTH.max()
# Out:
# 15063.6601049869

# %%
well_0_PHIF.DEPTH.min()
# Out:
# 11709.1601049869

# %%
well_0_PHIF.DEPTH.max()
# Out:
# 15151.1601049869

# %%
well_0_SW.DEPTH.min()
# Out:
# 11709.1601049869

# %%
well_0_SW.DEPTH.max()
# Out:
# 15151.1601049869

# %%
depth_well0=pd.DataFrame({'PHIF':[well_0_PHIF.DEPTH.max(),well_0_PHIF.DEPTH.min()], 'SW':[well_0_SW.DEPTH.max(),well_0_SW.DEPTH.min()], 'VSH':[well_0_VSH.DEPTH.max(),well_0_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])

# %%
depth_well0
# Out:
#                 PHIF            SW           VSH
# TOP     15151.160105  15151.160105  15063.660105
# BOTTOM  11709.160105  11709.160105  14121.660105

# %%
well_1 = pd.read_csv("well_1.csv")
well_1_PHIF = well_1.loc[well_1.PHIF.notnull()]
well_1_SW = well_1.loc[well_1.SW.notnull()]
well_1_VSH = well_1.loc[well_1.VSH.notnull()]
depth_well1 = pd.DataFrame({'PHIF':[well_1_PHIF.DEPTH.max(),well_1_PHIF.DEPTH.min()], 'SW':[well_1_SW.DEPTH.max(),well_1_SW.DEPTH.min()], 'VSH':[well_1_VSH.DEPTH.max(),well_1_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well1
# Out:
#             PHIF        SW       VSH
# TOP     11833.33  11833.33  11890.75
# BOTTOM  10891.40  10891.40  10731.63

# %%
well_2 = pd.read_csv("well_2.csv")
well_2_PHIF = well_2.loc[well_2.PHIF.notnull()]
well_2_SW = well_2.loc[well_2.SW.notnull()]
well_2_VSH = well_2.loc[well_2.VSH.notnull()]
depth_well2 = pd.DataFrame({'PHIF':[well_2_PHIF.DEPTH.max(),well_2_PHIF.DEPTH.min()], 'SW':[well_2_SW.DEPTH.max(),well_2_SW.DEPTH.min()], 'VSH':[well_2_VSH.DEPTH.max(),well_2_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well2
# Out:
#             PHIF        SW       VSH
# TOP     11999.34  11999.34  12055.45
# BOTTOM  11251.31  11251.31  11017.06

# %%
well_3 = pd.read_csv("well_3.csv")
well_3_PHIF = well_3.loc[well_3.PHIF.notnull()]
well_3_SW = well_3.loc[well_3.SW.notnull()]
well_3_VSH = well_3.loc[well_3.VSH.notnull()]
depth_well3 = pd.DataFrame({'PHIF':[well_3_PHIF.DEPTH.max(),well_3_PHIF.DEPTH.min()], 'SW':[well_3_SW.DEPTH.max(),well_3_SW.DEPTH.min()], 'VSH':[well_3_VSH.DEPTH.max(),well_3_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well3
# Out:
#             PHIF        SW       VSH
# TOP     11285.43  11285.43  11342.52
# BOTTOM  10595.14  10595.14  10511.81

# %%
well_4 = pd.read_csv("well_4.csv")
well_4_PHIF = well_4.loc[well_4.PHIF.notnull()]
well_4_SW = well_4.loc[well_4.SW.notnull()]
well_4_VSH = well_4.loc[well_4.VSH.notnull()]
depth_well4 = pd.DataFrame({'PHIF':[well_4_PHIF.DEPTH.max(),well_4_PHIF.DEPTH.min()], 'SW':[well_4_SW.DEPTH.max(),well_4_SW.DEPTH.min()], 'VSH':[well_4_VSH.DEPTH.max(),well_4_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well4
# Out:
#             PHIF        SW       VSH
# TOP     13344.49  13344.49  13421.26
# BOTTOM  10574.15  10574.15  10574.15

# %%
well_5 = pd.read_csv("well_5.csv")
well_5_PHIF = well_5.loc[well_5.PHIF.notnull()]
well_5_SW = well_5.loc[well_5.SW.notnull()]
well_5_VSH = well_5.loc[well_5.VSH.notnull()]
depth_well5 = pd.DataFrame({'PHIF':[well_5_PHIF.DEPTH.max(),well_5_PHIF.DEPTH.min()], 'SW':[well_5_SW.DEPTH.max(),well_5_SW.DEPTH.min()], 'VSH':[well_5_VSH.DEPTH.max(),well_5_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well5
# Out:
#             PHIF        SW       VSH
# TOP     12259.51  12259.51  12307.74
# BOTTOM  11729.00  11729.00  11729.00

# %%
well_6 = pd.read_csv("well_6.csv")
well_6_PHIF = well_6.loc[well_6.PHIF.notnull()]
well_6_SW = well_6.loc[well_6.SW.notnull()]
well_6_VSH = well_6.loc[well_6.VSH.notnull()]
depth_well6 = pd.DataFrame({'PHIF':[well_6_PHIF.DEPTH.max(),well_6_PHIF.DEPTH.min()], 'SW':[well_6_SW.DEPTH.max(),well_6_SW.DEPTH.min()], 'VSH':[well_6_VSH.DEPTH.max(),well_6_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well6
# Out:
#             PHIF        SW       VSH
# TOP     15566.93  15566.93  15614.17
# BOTTOM  10996.06  10996.06  10996.06

# %%
well_7 = pd.read_csv("well_7.csv")
well_7_PHIF = well_7.loc[well_7.PHIF.notnull()]
well_7_SW = well_7.loc[well_7.SW.notnull()]
well_7_VSH = well_7.loc[well_7.VSH.notnull()]
depth_well7 = pd.DataFrame({'PHIF':[well_7_PHIF.DEPTH.max(),well_7_PHIF.DEPTH.min()], 'SW':[well_7_SW.DEPTH.max(),well_7_SW.DEPTH.min()], 'VSH':[well_7_VSH.DEPTH.max(),well_7_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well7
# Out:
#             PHIF        SW       VSH
# TOP     14882.87  14882.87  14931.10
# BOTTOM  14221.46  14221.46  14221.46

# %%
well_8 = pd.read_csv("well_8.csv")
well_8_PHIF = well_8.loc[well_8.PHIF.notnull()]
well_8_SW = well_8.loc[well_8.SW.notnull()]
well_8_VSH = well_8.loc[well_8.VSH.notnull()]
depth_well8 = pd.DataFrame({'PHIF':[well_8_PHIF.DEPTH.max(),well_8_PHIF.DEPTH.min()], 'SW':[well_8_SW.DEPTH.max(),well_8_SW.DEPTH.min()], 'VSH':[well_8_VSH.DEPTH.max(),well_8_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
depth_well8
# Out:
#            PHIF       SW      VSH
# TOP     12144.5  12144.5  12144.5
# BOTTOM   8494.0   8494.0   8494.0

# %%
#Saving well data in dataframes
well_0 = pd.read_csv("well_0.csv")
well_1 = pd.read_csv("well_1.csv")
well_2 = pd.read_csv("well_2.csv")
well_3 = pd.read_csv("well_3.csv")
well_4 = pd.read_csv("well_4.csv")
well_5 = pd.read_csv("well_5.csv")
well_6 = pd.read_csv("well_6.csv")
well_7 = pd.read_csv("well_7.csv")
well_8 = pd.read_csv("well_8.csv")

#Comparing depths with data in the Petrophysical parameters PHIF, SW and VSH columns per well
for well in [well_0, well_1, well_2, well_3, well_4, well_5, well_6, well_7, well_8]:
    well_PHIF = well.loc[well.PHIF.notnull()]
    well_SW = well.loc[well.SW.notnull()]
    well_VSH = well.loc[well.VSH.notnull()]
    depth_well = pd.DataFrame({'PHIF':[well_PHIF.DEPTH.max(),well_PHIF.DEPTH.min()], 'SW':[well_SW.DEPTH.max(),well_SW.DEPTH.min()], 'VSH':[well_VSH.DEPTH.max(),well_VSH.DEPTH.min()]}, index=['TOP', 'BOTTOM'])
    print (depth_well)
# Out:
#                 PHIF            SW           VSH
# TOP     15151.160105  15151.160105  15063.660105
# BOTTOM  11709.160105  11709.160105  14121.660105
#             PHIF        SW       VSH
# TOP     11833.33  11833.33  11890.75
# BOTTOM  10891.40  10891.40  10731.63
#             PHIF        SW       VSH
# TOP     11999.34  11999.34  12055.45
# BOTTOM  11251.31  11251.31  11017.06
#             PHIF        SW       VSH
# TOP     11285.43  11285.43  11342.52
# BOTTOM  10595.14  10595.14  10511.81
#             PHIF        SW       VSH
# TOP     13344.49  13344.49  13421.26
# BOTTOM  10574.15  10574.15  10574.15
#             PHIF        SW       VSH
# TOP     12259.51  12259.51  12307.74
# BOTTOM  11729.00  11729.00  11729.00
#             PHIF        SW       VSH
# TOP     15566.93  15566.93  15614.17
# BOTTOM  10996.06  10996.06  10996.06
#             PHIF        SW       VSH
# TOP     14882.87  14882.87  14931.10
# BOTTOM  14221.46  14221.46  14221.46
# ...

# %%
whole_depth = pd.concat([depth_well0, depth_well1, depth_well2, depth_well3, depth_well4, depth_well5, depth_well6, depth_well7, depth_well8])
whole_depth
# Out:
#                 PHIF            SW           VSH
# TOP     15151.160105  15151.160105  15063.660105
# BOTTOM  11709.160105  11709.160105  14121.660105
# TOP     11833.330000  11833.330000  11890.750000
# BOTTOM  10891.400000  10891.400000  10731.630000
# TOP     11999.340000  11999.340000  12055.450000
# BOTTOM  11251.310000  11251.310000  11017.060000
# TOP     11285.430000  11285.430000  11342.520000
# BOTTOM  10595.140000  10595.140000  10511.810000
# TOP     13344.490000  13344.490000  13421.260000
# BOTTOM  10574.150000  10574.150000  10574.150000
# TOP     12259.510000  12259.510000  12307.740000
# BOTTOM  11729.000000  11729.000000  11729.000000
# TOP     15566.930000  15566.930000  15614.170000
# BOTTOM  10996.060000  10996.060000  10996.060000
# TOP     14882.870000  14882.870000  14931.100000
# BOTTOM  14221.460000  14221.460000  14221.460000
# TOP     12144.500000  12144.500000  12144.500000
# BOTTOM   8494.000000   8494.000000   8494.000000
